# %% [markdown]
# # Tips

# %% [markdown]
# ### Introduction:
#
#
#
# ### Step 1. Import the necessary libraries:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Step 2. Import the dataset

# %%
pd.read_csv('tips.csv')
# Out:
#      Unnamed: 0  total_bill   tip     sex smoker   day    time  size
# 0             0       16.99  1.01  Female     No   Sun  Dinner     2
# 1             1       10.34  1.66    Male     No   Sun  Dinner     3
# 2             2       21.01  3.50    Male     No   Sun  Dinner     3
# 3             3       23.68  3.31    Male     No   Sun  Dinner     2
# 4             4       24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...         ...   ...     ...    ...   ...     ...   ...
# 239         239       29.03  5.92    Male     No   Sat  Dinner     3
# 240         240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241         241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242         242       17.82  1.75    Male     No   Sat  Dinner     2
# 243         243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 8 columns]

# %% [markdown]
# ### Step 3. Assign it to a variable called tips

# %%
tips = pd.read_csv('tips.csv')

# %% [markdown]
# ### Step 4. Delete the Unnamed 0 column

# %%
del tips['Unnamed: 0']

# %% [markdown]
# ### Step 5. Plot the total_bill column histogram

# %%
plt.hist(tips['total_bill'])
plt.title('Total Bill Distribution')
plt.show()

# %%
x = sns.displot(tips['total_bill'])

# %%
x = sns.distplot(tips['total_bill'])
sns.despine()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_17036\904328425.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   x = sns.distplot(tips['total_bill'])

# %%
x = sns.histplot(tips['total_bill'])
x.set(xlabel='values', ylabel='frequency', title='Total Bill Distribution')
sns.despine()

# %% [markdown]
# ### Step 6. Create a scatter plot presenting the relationship between total_bill and tip

# %%
plt.scatter(data=tips, x='total_bill', y='tip')
plt.title('scatter plot')
# Out:
# Text(0.5, 1.0, 'scatter plot')

# %%
sns.scatterplot(data=tips, x='total_bill', y='tip', legend=True, hue='day')
sns.despine()

# %%
sns.scatterplot(data=tips, x='total_bill', y='tip', legend=True, hue='time')
sns.despine()

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
sns.scatterplot(data=tips, x='total_bill', y='tip', legend=True, hue='sex')
sns.despine()

# %% [markdown]
# ### Step 7.  Create one image with the relationship of total_bill, tip and size.
# #### Hint: It is just one function.

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
sns.pairplot(tips)

# %% [markdown]
# ### Step 8. Present the relationship between days and total_bill value

# %%
sns.stripplot(data=tips, x='day', y='total_bill', hue='day')
sns.despine()

# %% [markdown]
# ### Step 9. Create a scatter plot with the day as the y-axis and tip as the x-axis, differ the dots by sex

# %%
sns.scatterplot(data=tips, x='tip', y='day', hue='sex')
# Out:
# <Axes: xlabel='tip', ylabel='day'>

# %% [markdown]
# ### Step 10.  Create a box plot presenting the total_bill per day differetiation the time (Dinner or Lunch)

# %%
plt.figure(figsize=(10,5))
x=sns.boxplot(data=tips, x='day', y='total_bill', hue='time')
x.set(title="Total Bill per Day by Time", xlabel="Day", ylabel="Total Bill")
# sns.despine()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Step 11. Create two histograms of the tip value based for Dinner and Lunch. They must be side by side.

# %%
x=sns.histplot(data=tips[tips['time']=='Dinner'], x='tip', bins=10)
x.set(xlabel='Tips', ylabel='Frequency', title='Distribution of tip based time Dinner')
# label = range(11)
# plt.xticks(label)
x=sns.histplot(data=tips[tips['time']=='Lunch'], x='tip', bins=10)
x.set(xlabel='Tips', ylabel='Frequency', title='Distribution of tip based time Lunch')
plt.show()

# %% [markdown]
# ### Step 12. Create two scatterplots graphs, one for Male and another for Female, presenting the total_bill value and tip relationship, differing by smoker or no smoker
# ### They must be side by side.

# %% [markdown]
# ### BONUS: Create your own question and answer it using a graph.

# %%
student = ['r', 'b', 'y', 'g']
marks = [20, 90, 48, 54]

# %%
plt.plot(student, marks, color='r', marker='o')
plt.xlabel('students')
plt.ylabel('Marks')
plt.xticks(student)
plt.yticks(marks)
plt.title("Student's marks ")
plt.grid(True)
plt.show()

# %%
sns.lineplot(x=student, y=marks)
# Out:
# <Axes: >

# %%
plt.bar(student, marks, width=0.5)
plt.show()

# %%
sns.barplot(x=student,y=marks)
# Out:
# <Axes: >
